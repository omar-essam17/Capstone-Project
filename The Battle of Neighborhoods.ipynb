# %%
import pandas as pd
import numpy as np
import requests
import matplotlib
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 7.1MB/s ta 0:00:011
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
# get information about neighborhoods in toronto from wikipedia and save it in a variable
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
tor_neigh = requests.get(url).content
df_tor_neigh = pd.read_html(tor_neigh, header=0)[0]
df_tor_neigh.head(10)
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M1A      Not assigned                                 Not assigned
# 1         M2A      Not assigned                                 Not assigned
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7         M8A      Not assigned                                 Not assigned
# 8         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9         M1B       Scarborough                               Malvern, Rouge

# %%
# remove "Not assigned" values and cleaning the data
df_tor = df_tor_neigh[df_tor_neigh.Borough != 'Not assigned']

# drop duplicates values from the data frame
df_tor = df_tor.drop_duplicates()

# rename the columns into PostalCode & Neighborhood
df_tor.rename(columns = {"Postal Code":"PostalCode", "Neighbourhood":"Neighborhood"} , inplace = True)
df_tor.reset_index(inplace=True, drop=True) # rest the index
df_tor
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# 5              Islington Avenue, Humber Valley Village
# 6                                       Malvern, Rouge
# 7                                            Don Mills
# 8                      Parkview Hill, Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 12              Rouge Hill, Port Union, Highland Creek
# 13                                           Don Mills
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Wilson Heights, Downsview North
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                   North Toronto West, Lawrence Park
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, St. Phillips, Martin Grove ...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      University of Toronto, Harbord
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Tam O'Shanter, Sullivan
# 83                         Moore Park, Summerhill East
# 84           Kensington Market, Chinatown, Grange Park
# 85   Milliken, Agincourt North, Steeles East, L'Amo...
# 86   Summerhill West, Rathnelly, South Hill, Forest...
# 87   CN Tower, King and Spadina, Railway Lands, Har...
# 88        New Toronto, Mimico South, Humber Bay Shores
# 89   South Steeles, Silverstone, Humbergate, Jamest...
# 90                       Steeles West, L'Amoreaux West
# 91                                            Rosedale
# 92                                      Stn A PO Boxes
# 93                              Alderwood, Long Branch
# 94                 Northwest, West Humber - Clairville
# 95                                         Upper Rouge
# 96                         St. James Town, Cabbagetown
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
# read the csv file that has the geographical coordinates of each postal code
df_geo = pd.read_csv("https://cocl.us/Geospatial_data")
df_geo.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
# make a new data the merge the two data frames with replacing the postal code column
df_geo1 = df_tor.join(df_geo.set_index("Postal Code"), on="PostalCode")
df_geo1.head(10)
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5        M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 6        M1B       Scarborough                               Malvern, Rouge
# 7        M3B        North York                                    Don Mills
# 8        M4B         East York              Parkview Hill, Woodbine Gardens
# 9        M5B  Downtown Toronto                     Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937

# %%
CLIENT_ID = 'A2TT1WZQUPK0CV1PGPGQW5EUAFP1XGH2PZT5AWF3022F5FYG'
CLIENT_SECRET = '0X15FO2ORCPYLBC3ROLDGBOMAX4S1GHCYPER0J5J3HYHBU4R'
VERSION = '20200726'
LIMIT = 1000

# %%
# lets say that you are in the centre fo toronto 
latitude = 43.653908
longitude = -79.384293
search_query = "Pizza"
radius = 5000

# %%
for_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
for_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A2TT1WZQUPK0CV1PGPGQW5EUAFP1XGH2PZT5AWF3022F5FYG&client_secret=0X15FO2ORCPYLBC3ROLDGBOMAX4S1GHCYPER0J5J3HYHBU4R&ll=43.653908,-79.384293&v=20200726&query=Pizza&radius=5000&limit=1000'

# %%
import json
results = requests.get(for_url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1ebd11ccc8c705d049aca8'},
#  'response': {'venues': [{'id': '4b2438f6f964a520126424e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '260 CHURCH STREET',
#      'lat': 43.65651263631174,
#      'lng': -79.37724160484107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65651263631174,
#        'lng': -79.37724160484107}],
#      'distance': 637,
#      'postalCode': 'M5B 1Z2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['260 CHURCH STREET',
#       'Toronto ON M5B 1Z2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '552ff1d1498e5f41b0ccb3bd',
#     'name': "Mamma's Pizza",
#     'location': {'address': '127 Yonge St',
#      'lat': 43.650891,
#      'lng': -79.378632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650891,
#        'lng': -79.378632}],
#      'distance': 566,
#      'postalCode': 'M5C 1W4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['127 Yonge St', 'Toronto ON M5C 1W4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ca62112f47ea14380845d21',
#     'name': 'Pizza 2 Go',
#     'location': {'address': '65 Front St. W',
#      'crossStreet': 'Union Station',
#      'lat': 43.64608978691595,
#      'lng': -79.37977562557961,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64608978691595,
#        'lng': -79.37977562557961}],
#      'distance': 943,
#      'postalCode': 'M5J',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['65 Front St. W (Union Station)',
#       'Toronto ON M5J',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '59f28358acb00b73e36783d6',
#     'name': "Domino's Pizza",
#     'location': {'address': '67 Richmond St E',
#      'lat': 43.65245635983421,
#      'lng': -79.37493822948448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65245635983421,
#        'lng': -79.37493822948448}],
#      'distance': 770,
#      'postalCode': 'M5C 1N9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['67 Richmond St E', 'Toronto ON M5C 1N9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4af5d885f964a520b2fd21e3',
#     'name': 'Amato Pizza',
#     'location': {'address': '429A Yonge St',
#      'crossStreet': 'at College St',
#      'lat': 43.66021482917061,
#      'lng': -79.38257133039714,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66021482917061,
#        'lng': -79.38257133039714}],
#      'distance': 715,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['429A Yonge St (at College St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5690363d498e0b868217831d',
#     'name': 'JZs Pizza',
#     'location': {'address': '232 Wellington St W',
#      'lat': 43.645145,
#      'lng': -79.389296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645145,
#        'lng': -79.389296}],
#      'distance': 1055,
#      'postalCode': 'M5V 3W1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['232 Wellington St W',
#       'Toronto ON M5V 3W1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b5fdb7ff964a520ebce29e3',
#     'name': 'Express Pizza',
#     'location': {'address': '447 Church St.',
#      'crossStreet': 'at Alexander St.',
#      'lat': 43.66378730691813,
#      'lng': -79.38022420876023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66378730691813,
#        'lng': -79.38022420876023}],
#      'distance': 1147,
#      'postalCode': 'M4Y 2C5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['447 Church St. (at Alexander St.)',
#       'Toronto ON M4Y 2C5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4dde735f7d8bb03c06b3db73',
#     'name': 'Boston Pizza',
#     'location': {'address': '250 Front St W Unit 1c201',
#      'crossStreet': 'John St',
#      'lat': 43.64405883528329,
#      'lng': -79.38881541663336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64405883528329,
#        'lng': -79.38881541663336}],
#      'distance': 1155,
#      'postalCode': 'M5V 3G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Front St W Unit 1c201 (John St)',
#       'Toronto ON M5V 3G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4af23cabf964a520d4e621e3',
#     'name': 'Pizza Rustica Restaurant & Bar',
#     'location': {'address': '37 Blue Jays Way',
#      'lat': 43.64491920354413,
#      'lng': -79.3918436177755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64491920354413,
#        'lng': -79.3918436177755}],
#      'distance': 1170,
#      'postalCode': 'M5V 3P5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 Blue Jays Way', 'Toronto ON M5V 3P5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4cdd8afb78ddf04dfbf29498',
#     'name': 'St. Lawrence Pizza and Pasta',
#     'location': {'address': '93 Front St. E.',
#      'crossStreet': 'St Lawrence Market (Upper Level 36)',
#      'lat': 43.64837838784134,
#      'lng': -79.37157761069746,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64837838784134,
#        'lng': -79.37157761069746}],
#      'distance': 1194,
#      'postalCode': 'M5E 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['93 Front St. E. (St Lawrence Market (Upper Level 36))',
#       'Toronto ON M5E 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b7f161bf964a5206e1530e3',
#     'name': 'Pizza Nova',
#     'location': {'address': '371 Front Street W',
#      'crossStreet': 'at Blue Jay Way',
#      'lat': 43.64327168873745,
#      'lng': -79.39183585267101,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64327168873745,
#        'lng': -79.39183585267101}],
#      'distance': 1330,
#      'postalCode': 'M5V 3S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['371 Front Street W (at Blue Jay Way)',
#       'Toronto ON M5V 3S8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bccdaca68f976b036686383',
#     'name': "Mamma's Pizza",
#     'location': {'address': '249 Queens Quay W',
#      'lat': 43.63904861970403,
#      'lng': -79.38632341824247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63904861970403,
#        'lng': -79.38632341824247}],
#      'distance': 1662,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['249 Queens Quay W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4adc9f99f964a520092e21e3',
#     'name': "Mamma's Pizza",
#     'location': {'address': '405 Richmond St. W',
#      'crossStreet': 'at Spadina Ave.',
#      'lat': 43.64794272203376,
#      'lng': -79.3956474811735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64794272203376,
#        'lng': -79.3956474811735}],
#      'distance': 1130,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['405 Richmond St. W (at Spadina Ave.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5968973e93bd637ca76c60c8',
#     'name': '241 Pizza',
#     'location': {'address': '142 Parliament St.',
#      'lat': 43.6546222,
#      'lng': -79.3642113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6546222,
#        'lng': -79.3642113}],
#      'distance': 1619,
#      'postalCode': 'M5A 2Z1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['142 Parliament St.',
#       'Toronto ON M5A 2Z1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bc3a04cabf49521650bc493',
#     'name': 'Pizza Pizza',
#     'location': {'address': '655 Queen St W',
#      'lat': 43.64711589206853,
#      'lng': -79.40415196491139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64711589206853,
#        'lng': -79.40415196491139}],
#      'distance': 1769,
#      'postalCode': 'M6J 1E8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['655 Queen St W', 'Toronto ON M6J 1E8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bf4172998ac0f474f9163a8',
#     'name': '241 Pizza',
#     'location': {'address': '451 Parliament St',
#      'crossStreet': 'Spruce St',
#      'lat': 43.663488,
#      'lng': -79.36755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663488,
#        'lng': -79.36755}],
#      'distance': 1719,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['451 Parliament St (Spruce St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b50edc9f964a5201c3927e3',
#     'name': 'Pizzaiolo',
#     'location': {'address': '289 Dundas St',
#      'crossStreet': 'at McCaul St',
#      'lat': 43.654332488625734,
#      'lng': -79.39110722018398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654332488625734,
#        'lng': -79.39110722018398}],
#      'distance': 550,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['289 Dundas St (at McCaul St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ad4c05ff964a52014f720e3',
#     'name': 'Papa Ceo Fine Italian Foods & Pizza',
#     'location': {'address': '654 Spadina Avenue',
#      'lat': 43.66329982959619,
#      'lng': -79.40231705278073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66329982959619,
#        'lng': -79.40231705278073}],
#      'distance': 1788,
#      'postalCode': 'M5S 2H7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['654 Spadina Avenue',
#       'Toronto ON M5S 2H7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b8095c0f964a520d47e30e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '678 QUEEN STREET EAST',
#      'lat': 43.65865441760277,
#      'lng': -79.35095548089345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65865441760277,
#        'lng': -79.35095548089345}],
#      'distance': 2736,
#      'postalCode': 'M4M 1G8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['678 QUEEN STREET EAST',
#       'Toronto ON M4M 1G8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5c53a0aea2a6ce002c9e3806',
#     'name': 'Pizza Shab',
#     'location': {'lat': 43.656972,
#      'lng': -79.378484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656972,
#        'lng': -79.378484}],
#      'distance': 578,
#      'postalCode': 'M5B 1Y2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5B 1Y2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ae27484f964a520648e21e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '328 Bloor St. W',
#      'lat': 43.666777262381885,
#      'lng': -79.40352861491873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.666777262381885,
#        'lng': -79.40352861491873}],
#      'distance': 2109,
#      'postalCode': 'M5S 1W5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['328 Bloor St. W', 'Toronto ON M5S 1W5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ca36ac2b0ff8cfa4d24b75e',
#     'name': 'Pizza Pizza',
#     'location': {'address': 'Avenue of the Island',
#      'lat': 43.622236580347796,
#      'lng': -79.37893509864807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.622236580347796,
#        'lng': -79.37893509864807}],
#      'distance': 3551,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Avenue of the Island', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4c787c9181bca0936180fa14',
#     'name': 'Classic italian style pizza food truck',
#     'location': {'address': 'CNE Midway',
#      'lat': 43.652144,
#      'lng': -79.381118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652144,
#        'lng': -79.381118}],
#      'distance': 322,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5c789831180b91003915b599',
#     'name': 'Pizza Forno',
#     'location': {'address': '217 Adelaide St West',
#      'lat': 43.64829,
#      'lng': -79.387505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64829,
#        'lng': -79.387505}],
#      'distance': 676,
#      'postalCode': 'M5H 1W7',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['217 Adelaide St West',
#       'Toronto ON M5H 1W7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b7ddd2cf964a52001d82fe3',
#     'name': "Vinnie's Pizza & Pasta",
#     'location': {'address': '595 Bay St.',
#      'crossStreet': 'in Atrium On Bay',
#      'lat': 43.65621225108779,
#      'lng': -79.38342961537722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65621225108779,
#        'lng': -79.38342961537722}],
#      'distance': 265,
#      'postalCode': 'M5G 2M6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St. (in Atrium On Bay)',
#       'Toronto ON M5G 2M6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5a9b3ef3d1a40244fc9e8373',
#     'name': 'The Good Son Pizza',
#     'location': {'address': '111 Richmond St w',
#      'lat': 43.650696,
#      'lng': -79.384149,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650696,
#        'lng': -79.384149}],
#      'distance': 357,
#      'postalCode': 'M5H 2G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Richmond St w',
#       'Toronto ON M5H 2G4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4aef9318f964a52059d921e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '558 BLOOR STREET WEST',
#      'lat': 43.665031107963934,
#      'lng': -79.41121816635132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.665031107963934,
#        'lng': -79.41121816635132}],
#      'distance': 2497,
#      'postalCode': 'M5S 1Y6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['558 BLOOR STREET WEST',
#       'Toronto ON M5S 1Y6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4e8684e2b803d7b67f5c7c3f',
#     'name': 'Pizza Nova',
#     'location': {'address': 'Jarvis',
#      'crossStreet': 'Dundas',
#      'lat': 43.65715687330202,
#      'lng': -79.3740019672304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65715687330202,
#        'lng': -79.3740019672304}],
#      'distance': 904,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Jarvis (Dundas)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5b0ed8c9d0a149002c9927bb',
#     'name': 'Pizza Rustica',
#     'location': {'address': '95 King Street East',
#      'lat': 43.649834,
#      'lng': -79.374809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649834,
#        'lng': -79.374809}],
#      'distance': 888,
#      'postalCode': 'M5C 2V8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['95 King Street East',
#       'Toronto ON M5C 2V8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bd33bd6b221c9b6f235d9d0',
#     'name': 'Pizza Hut',
#     'location': {'address': '200 Dundas St E',
#      'crossStreet': 'btwn Jarvis & George',
#      'lat': 43.657087846294495,
#      'lng': -79.37412294281036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657087846294495,
#        'lng': -79.37412294281036}],
#      'distance': 892,
#      'postalCode': 'M5A 4R6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Dundas St E (btwn Jarvis & George)',
#       'Toronto ON M5A 4R6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5f06d9a7499da0761966014a',
#     'name': 'Domino’s Pizza',
#     'location': {'crossStreet': 'College',
#      'lat': 43.662363,
#      'lng': -79.383626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.662363,
#        'lng': -79.383626}],
#      'distance': 942,
#      'postalCode': 'M4Y 3B3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['College', 'Toronto ON M4Y 3B3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bca3d4cb6c49c74e7209091',
#     'name': 'Pizza Pizza',
#     'location': {'address': '761 Bay St',
#      'lat': 43.65948714793604,
#      'lng': -79.3852073537072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65948714793604,
#        'lng': -79.3852073537072}],
#      'distance': 625,
#      'postalCode': 'M5G 2R2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['761 Bay St', 'Toronto ON M5G 2R2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '504f3f4dc84ca7853139f4c2',
#     'name': 'Freshslice Pizza',
#     'location': {'address': '250 Dundas Street West',
#      'crossStreet': 'Dundas & University',
#      'lat': 43.654529128495966,
#      'lng': -79.39009454730932,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654529128495966,
#        'lng': -79.39009454730932}],
#      'distance': 472,
#      'postalCode': 'M7A 1G1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Dundas Street West (Dundas & University)',
#       'Toronto ON M7A 1G1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ce805f68ef78cfa1675979b',
#     'name': 'Pizza Pizza',
#     'location': {'address': '346 YONGE STREET',
#      'lat': 43.65787913074364,
#      'lng': -79.38172941042963,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65787913074364,
#        'lng': -79.38172941042963}],
#      'distance': 487,
#      'postalCode': 'M5B 1R8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['346 YONGE STREET', 'Toronto ON M5B 1R8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5aa59c977564f726ae4069c6',
#     'name': 'Big Trouble Pizza',
#     'location': {'address': '235 Spadina Ave',
#      'crossStreet': 'Dundas St. W',
#      'lat': 43.651347,
#      'lng': -79.39702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651347,
#        'lng': -79.39702}],
#      'distance': 1063,
#      'postalCode': 'M5T 2E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['235 Spadina Ave (Dundas St. W)',
#       'Toronto ON M5T 2E2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '59ecdaae029a5529f5e8773c',
#     'name': 'Boston Pizza',
#     'location': {'address': '407 Yonge Street',
#      'lat': 43.659338317692985,
#      'lng': -79.38226037293168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659338317692985,
#        'lng': -79.38226037293168}],
#      'distance': 626,
#      'postalCode': 'M5G 2K2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['407 Yonge Street', 'Toronto ON M5G 2K2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '524a5b79498e2a7a5945a8e1',
#     'name': "Mamma's Pizza",
#     'location': {'address': 'Yonge St.',
#      'lat': 43.659155,
#      'lng': -79.383018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659155,
#        'lng': -79.383018}],
#      'distance': 593,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge St.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5615b6c4498e3c32c67ad78f',
#     'name': 'Blaze Pizza',
#     'location': {'address': '10 Dundas Street East, #124',
#      'lat': 43.656518,
#      'lng': -79.380015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656518,
#        'lng': -79.380015}],
#      'distance': 450,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas Street East, #124',
#       'Toronto ON M5B 2G9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b6b0234f964a52043ec2be3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '228 QUEEN STREET WEST',
#      'lat': 43.65010669805269,
#      'lng': -79.39000182194306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65010669805269,
#        'lng': -79.39000182194306}],
#      'distance': 624,
#      'postalCode': 'M5V 1Z6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['228 QUEEN STREET WEST',
#       'Toronto ON M5V 1Z6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '522b40ce11d2a3a8907697a9',
#     'name': 'Pizza & Pasta',
#     'location': {'crossStreet': 'Front and Jervis',
#      'lat': 43.6476,
#      'lng': -79.3735,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.6476, 'lng': -79.3735}],
#      'distance': 1117,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Front and Jervis', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4ffc93cce4b001c1ca261790',
#     'name': "Colombo's Pizza",
#     'location': {'lat': 43.65833282470703,
#      'lng': -79.37913513183594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65833282470703,
#        'lng': -79.37913513183594}],
#      'distance': 644,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5129ce16e4b0447baceddbd1',
#     'name': "Andrew's Pizza",
#     'location': {'lat': 43.659928,
#      'lng': -79.385044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659928,
#        'lng': -79.385044}],
#      'distance': 672,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4aeb18d8f964a5204bbe21e3',
#     'name': 'Pizzaiolo',
#     'location': {'address': '521 King St. W',
#      'crossStreet': 'at Brant St.',
#      'lat': 43.64479341856585,
#      'lng': -79.3982296189393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64479341856585,
#        'lng': -79.3982296189393}],
#      'distance': 1513,
#      'postalCode': 'M5V 1K4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['521 King St. W (at Brant St.)',
#       'Toronto ON M5V 1K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4bb6f2f52f70c9b6232e8630',
#     'name': 'Delisso Pizza & Wings',
#     'location': {'address': '772 College St',
#      'lat': 43.6550191,
#      'lng': -79.420346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6550191,
#        'lng': -79.420346}],
#      'distance': 2906,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['772 College St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4aeef7caf964a520ecd421e3',
#     'name': 'Pizza Rustica Boutique',
#     'location': {'address': '232 wellington street west',
#      'crossStreet': 'John',
#      'lat': 43.64511516109716,
#      'lng': -79.38940583644242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64511516109716,
#        'lng': -79.38940583644242}],
#      'distance': 1061,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['232 wellington street west (John)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5b7331b00d8a0f002c4849bf',
#     'name': 'Za Pizza Bistro',
#     'location': {'address': '290 Adelaide Street West',
#      'lat': 43.64787,
#      'lng': -79.391136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64787,
#        'lng': -79.391136}],
#      'distance': 869,
#      'postalCode': 'M5V 1P6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['290 Adelaide Street West',
#       'Toronto ON M5V 1P6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '50a05c37e4b0577f9f1f1ba6',
#     'name': 'Pizza Pizza',
#     'location': {'address': '109 FRONT STREET EAST',
#      'lat': 43.6496176296263,
#      'lng': -79.37109063796213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6496176296263,
#        'lng': -79.37109063796213}],
#      'distance': 1165,
#      'postalCode': 'M5E 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['109 FRONT STREET EAST',
#       'Toronto ON M5E 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '4b8216c4f964a5203dca30e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '1193 BLOOR STREET WEST',
#      'lat': 43.6591696173578,
#      'lng': -79.4386568356875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6591696173578,
#        'lng': -79.4386568356875}],
#      'distance': 4417,
#      'postalCode': 'M6H 1N4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1193 BLOOR STREET WEST',
#       'Toronto ON M6H 1N4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '57c86064498e77ac07cf2730',
#     'name': 'King David Pizza',
#     'location': {'address': '600 University Ave',
#      'lat': 43.657524,
#      'lng': -79.390724,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657524,
#        'lng': -79.390724}],
#      'distance': 655,
#      'postalCode': 'M5G 1X5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 University Ave',
#       'Toronto ON M5G 1X5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False},
#    {'id': '5514dc35498e1babfbd4f5f6',
#     'name': "Papa John's Pizza",
#     'location': {'address': '255 E Dundas St., Ste E',
#      'lat': 43.65797992914537,
#      'lng': -79.37249553926944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65797992914537,
#        'lng': -79.37249553926944}],
#      'distance': 1052,
#      'postalCode': 'M5A 1Z7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 E Dundas St., Ste E',
#       'Toronto ON M5A 1Z7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595850184',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

df_pizza = json_normalize(venues)
df_pizza.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
#
#                          id   location.address location.cc location.city  \
# 0  4b2438f6f964a520126424e3  260 CHURCH STREET          CA       Toronto
# 1  552ff1d1498e5f41b0ccb3bd       127 Yonge St          CA       Toronto
# 2  4ca62112f47ea14380845d21     65 Front St. W          CA       Toronto
# 3  59f28358acb00b73e36783d6   67 Richmond St E          CA       Toronto
# 4  4af5d885f964a520b2fd21e3      429A Yonge St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                637
# 1           Canada                  NaN                566
# 2           Canada        Union Station                943
# 3           Canada                  NaN                770
# 4           Canada        at College St                715
#
#                            location.formattedAddress  \
# 0    [260 CHURCH STREET, Toronto ON M5B 1Z2, Canada]
# 1         [127 Yonge St, Toronto ON M5C 1W4, Canada]
# 2  [65 Front St. W (Union Station), Toronto ON M5...
# 3     [67 Richmond St E, Toronto ON M5C 1N9, Canada]
# 4  [429A Yonge St (at College St), Toronto ON, Ca...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65651263631174...     43.656513
# 1  [{'label': 'display', 'lat': 43.650891, 'lng':...     43.650891
# 2  [{'label': 'display', 'lat': 43.64608978691595...     43.646090
# 3  [{'label': 'display', 'lat': 43.65245635983421...     43.652456
# 4  [{'label': 'display', 'lat': 43.66021482917061...     43.660215
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.377242                   NaN             M5B 1Z2             ON
# 1    -79.378632                   NaN             M5C 1W4             ON
# 2    -79.379776                   NaN                 M5J             ON
# 3    -79.374938                   NaN             M5C 1N9             ON
# 4    -79.382571                   NaN                 NaN             ON
#
#              name    referralId
# 0     Pizza Pizza  v-1595850184
# 1   Mamma's Pizza  v-1595850184
# 2      Pizza 2 Go  v-1595850184
# 3  Domino's Pizza  v-1595850184
# 4     Amato Pizza  v-1595850184

# %%
# filter the columns and keep only that include name and anythin relate to location
filtered_columns = ['name', 'categories'] + [col for col in df_pizza.columns if col.startswith('location.')] + ['id']
df_filtered = df_pizza.loc[:, filtered_columns]
df_filtered.head()
# Out:
#              name                                         categories  \
# 0     Pizza Pizza  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 1   Mamma's Pizza  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 2      Pizza 2 Go  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 3  Domino's Pizza  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 4     Amato Pizza  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
#
#     location.address location.cc location.city location.country  \
# 0  260 CHURCH STREET          CA       Toronto           Canada
# 1       127 Yonge St          CA       Toronto           Canada
# 2     65 Front St. W          CA       Toronto           Canada
# 3   67 Richmond St E          CA       Toronto           Canada
# 4      429A Yonge St          CA       Toronto           Canada
#
#   location.crossStreet  location.distance  \
# 0                  NaN                637
# 1                  NaN                566
# 2        Union Station                943
# 3                  NaN                770
# 4        at College St                715
#
#                            location.formattedAddress  \
# 0    [260 CHURCH STREET, Toronto ON M5B 1Z2, Canada]
# 1         [127 Yonge St, Toronto ON M5C 1W4, Canada]
# 2  [65 Front St. W (Union Station), Toronto ON M5...
# 3     [67 Richmond St E, Toronto ON M5C 1N9, Canada]
# 4  [429A Yonge St (at College St), Toronto ON, Ca...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65651263631174...     43.656513
# 1  [{'label': 'display', 'lat': 43.650891, 'lng':...     43.650891
# 2  [{'label': 'display', 'lat': 43.64608978691595...     43.646090
# 3  [{'label': 'display', 'lat': 43.65245635983421...     43.652456
# 4  [{'label': 'display', 'lat': 43.66021482917061...     43.660215
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.377242                   NaN             M5B 1Z2             ON
# 1    -79.378632                   NaN             M5C 1W4             ON
# 2    -79.379776                   NaN                 M5J             ON
# 3    -79.374938                   NaN             M5C 1N9             ON
# 4    -79.382571                   NaN                 NaN             ON
#
#                          id
# 0  4b2438f6f964a520126424e3
# 1  552ff1d1498e5f41b0ccb3bd
# 2  4ca62112f47ea14380845d21
# 3  59f28358acb00b73e36783d6
# 4  4af5d885f964a520b2fd21e3

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

df_filtered['categories'] = df_filtered.apply(get_category_type, axis=1)

df_filtered.columns = [column.split('.')[-1] for column in df_filtered.columns]

df_filtered
# Out:
#                                       name          categories  \
# 0                              Pizza Pizza         Pizza Place
# 1                            Mamma's Pizza         Pizza Place
# 2                               Pizza 2 Go         Pizza Place
# 3                           Domino's Pizza         Pizza Place
# 4                              Amato Pizza         Pizza Place
# 5                                JZs Pizza  Italian Restaurant
# 6                            Express Pizza         Pizza Place
# 7                             Boston Pizza         Pizza Place
# 8           Pizza Rustica Restaurant & Bar         Pizza Place
# 9             St. Lawrence Pizza and Pasta  Italian Restaurant
# 10                              Pizza Nova         Pizza Place
# 11                           Mamma's Pizza         Pizza Place
# 12                           Mamma's Pizza         Pizza Place
# 13                               241 Pizza         Pizza Place
# 14                             Pizza Pizza         Pizza Place
# 15                               241 Pizza         Pizza Place
# 16                               Pizzaiolo         Pizza Place
# 17     Papa Ceo Fine Italian Foods & Pizza         Pizza Place
# 18                             Pizza Pizza         Pizza Place
# 19                              Pizza Shab         Pizza Place
# 20                             Pizza Pizza         Pizza Place
# 21                             Pizza Pizza         Pizza Place
# 22  Classic italian style pizza food truck          Food Truck
# 23                             Pizza Forno         Pizza Place
# 24                  Vinnie's Pizza & Pasta         Pizza Place
# 25                      The Good Son Pizza         Pizza Place
# 26                             Pizza Pizza         Pizza Place
# 27                              Pizza Nova         Pizza Place
# 28                           Pizza Rustica         Pizza Place
# 29                               Pizza Hut         Pizza Place
# 30                          Domino’s Pizza         Pizza Place
# 31                             Pizza Pizza         Pizza Place
# 32                        Freshslice Pizza         Pizza Place
# 33                             Pizza Pizza         Pizza Place
# 34                       Big Trouble Pizza         Pizza Place
# 35                            Boston Pizza         Pizza Place
# 36                           Mamma's Pizza         Pizza Place
# 37                             Blaze Pizza         Pizza Place
# 38                             Pizza Pizza         Pizza Place
# 39                           Pizza & Pasta   Food & Drink Shop
# 40                         Colombo's Pizza          Food Truck
# 41                          Andrew's Pizza         Pizza Place
# 42                               Pizzaiolo         Pizza Place
# 43                   Delisso Pizza & Wings         Pizza Place
# 44                  Pizza Rustica Boutique  Italian Restaurant
# 45                         Za Pizza Bistro         Pizza Place
# 46                             Pizza Pizza         Pizza Place
# 47                             Pizza Pizza         Pizza Place
# 48                        King David Pizza         Pizza Place
# 49                       Papa John's Pizza         Pizza Place
#
#                         address  cc     city country  \
# 0             260 CHURCH STREET  CA  Toronto  Canada
# 1                  127 Yonge St  CA  Toronto  Canada
# 2                65 Front St. W  CA  Toronto  Canada
# 3              67 Richmond St E  CA  Toronto  Canada
# 4                 429A Yonge St  CA  Toronto  Canada
# 5           232 Wellington St W  CA  Toronto  Canada
# 6                447 Church St.  CA  Toronto  Canada
# 7     250 Front St W Unit 1c201  CA  Toronto  Canada
# 8              37 Blue Jays Way  CA  Toronto  Canada
# 9               93 Front St. E.  CA  Toronto  Canada
# 10           371 Front Street W  CA  Toronto  Canada
# 11            249 Queens Quay W  CA  Toronto  Canada
# 12           405 Richmond St. W  CA  Toronto  Canada
# 13           142 Parliament St.  CA  Toronto  Canada
# 14               655 Queen St W  CA  Toronto  Canada
# 15            451 Parliament St  CA  Toronto  Canada
# 16                289 Dundas St  CA  Toronto  Canada
# 17           654 Spadina Avenue  CA  Toronto  Canada
# 18        678 QUEEN STREET EAST  CA  Toronto  Canada
# 19                          NaN  CA  Toronto  Canada
# 20              328 Bloor St. W  CA  Toronto  Canada
# 21         Avenue of the Island  CA  Toronto  Canada
# 22                   CNE Midway  CA  Toronto  Canada
# 23         217 Adelaide St West  CA  Toronto  Canada
# 24                  595 Bay St.  CA  Toronto  Canada
# 25            111 Richmond St w  CA  Toronto  Canada
# 26        558 BLOOR STREET WEST  CA  Toronto  Canada
# 27                       Jarvis  CA  Toronto  Canada
# 28          95 King Street East  CA  Toronto  Canada
# 29              200 Dundas St E  CA  Toronto  Canada
# 30                          NaN  CA  Toronto  Canada
# 31                   761 Bay St  CA  Toronto  Canada
# 32       250 Dundas Street West  CA  Toronto  Canada
# 33             346 YONGE STREET  CA  Toronto  Canada
# 34              235 Spadina Ave  CA  Toronto  Canada
# 35             407 Yonge Street  CA  Toronto  Canada
# 36                    Yonge St.  CA  Toronto  Canada
# 37  10 Dundas Street East, #124  CA  Toronto  Canada
# 38        228 QUEEN STREET WEST  CA  Toronto  Canada
# 39                          NaN  CA  Toronto  Canada
# 40                          NaN  CA      NaN  Canada
# 41                          NaN  CA      NaN  Canada
# 42               521 King St. W  CA  Toronto  Canada
# 43               772 College St  CA  Toronto  Canada
# 44   232 wellington street west  CA  Toronto  Canada
# 45     290 Adelaide Street West  CA  Toronto  Canada
# 46        109 FRONT STREET EAST  CA  Toronto  Canada
# 47       1193 BLOOR STREET WEST  CA  Toronto  Canada
# 48           600 University Ave  CA  Toronto  Canada
# 49      255 E Dundas St., Ste E  CA  Toronto  Canada
#
#                             crossStreet  distance  \
# 0                                   NaN       637
# 1                                   NaN       566
# 2                         Union Station       943
# 3                                   NaN       770
# 4                         at College St       715
# 5                                   NaN      1055
# 6                      at Alexander St.      1147
# 7                               John St      1155
# 8                                   NaN      1170
# 9   St Lawrence Market (Upper Level 36)      1194
# 10                      at Blue Jay Way      1330
# 11                                  NaN      1662
# 12                      at Spadina Ave.      1130
# 13                                  NaN      1619
# 14                                  NaN      1769
# 15                            Spruce St      1719
# 16                         at McCaul St       550
# 17                                  NaN      1788
# 18                                  NaN      2736
# 19                                  NaN       578
# 20                                  NaN      2109
# 21                                  NaN      3551
# 22                                  NaN       322
# 23                                  NaN       676
# 24                     in Atrium On Bay       265
# 25                                  NaN       357
# 26                                  NaN      2497
# 27                               Dundas       904
# 28                                  NaN       888
# 29                 btwn Jarvis & George       892
# 30                              College       942
# 31                                  NaN       625
# 32                  Dundas & University       472
# 33                                  NaN       487
# 34                         Dundas St. W      1063
# 35                                  NaN       626
# 36                                  NaN       593
# 37                                  NaN       450
# 38                                  NaN       624
# 39                     Front and Jervis      1117
# 40                                  NaN       644
# 41                                  NaN       672
# 42                         at Brant St.      1513
# 43                                  NaN      2906
# 44                                 John      1061
# 45                                  NaN       869
# 46                                  NaN      1165
# 47                                  NaN      4417
# 48                                  NaN       655
# 49                                  NaN      1052
#
#                                      formattedAddress  \
# 0     [260 CHURCH STREET, Toronto ON M5B 1Z2, Canada]
# 1          [127 Yonge St, Toronto ON M5C 1W4, Canada]
# 2   [65 Front St. W (Union Station), Toronto ON M5...
# 3      [67 Richmond St E, Toronto ON M5C 1N9, Canada]
# 4   [429A Yonge St (at College St), Toronto ON, Ca...
# 5   [232 Wellington St W, Toronto ON M5V 3W1, Canada]
# 6   [447 Church St. (at Alexander St.), Toronto ON...
# 7   [250 Front St W Unit 1c201 (John St), Toronto ...
# 8      [37 Blue Jays Way, Toronto ON M5V 3P5, Canada]
# 9   [93 Front St. E. (St Lawrence Market (Upper Le...
# 10  [371 Front Street W (at Blue Jay Way), Toronto...
# 11            [249 Queens Quay W, Toronto ON, Canada]
# 12  [405 Richmond St. W (at Spadina Ave.), Toronto...
# 13   [142 Parliament St., Toronto ON M5A 2Z1, Canada]
# 14       [655 Queen St W, Toronto ON M6J 1E8, Canada]
# 15  [451 Parliament St (Spruce St), Toronto ON, Ca...
# 16  [289 Dundas St (at McCaul St), Toronto ON, Can...
# 17   [654 Spadina Avenue, Toronto ON M5S 2H7, Canada]
# 18  [678 QUEEN STREET EAST, Toronto ON M4M 1G8, Ca...
# 19                       [Toronto ON M5B 1Y2, Canada]
# 20      [328 Bloor St. W, Toronto ON M5S 1W5, Canada]
# 21         [Avenue of the Island, Toronto ON, Canada]
# 22                   [CNE Midway, Toronto ON, Canada]
# 23  [217 Adelaide St West, Toronto ON M5H 1W7, Can...
# 24  [595 Bay St. (in Atrium On Bay), Toronto ON M5...
# 25    [111 Richmond St w, Toronto ON M5H 2G4, Canada]
# 26  [558 BLOOR STREET WEST, Toronto ON M5S 1Y6, Ca...
# 27              [Jarvis (Dundas), Toronto ON, Canada]
# 28  [95 King Street East, Toronto ON M5C 2V8, Canada]
# 29  [200 Dundas St E (btwn Jarvis & George), Toron...
# 30              [College, Toronto ON M4Y 3B3, Canada]
# 31           [761 Bay St, Toronto ON M5G 2R2, Canada]
# 32  [250 Dundas Street West (Dundas & University),...
# 33     [346 YONGE STREET, Toronto ON M5B 1R8, Canada]
# 34  [235 Spadina Ave (Dundas St. W), Toronto ON M5...
# 35     [407 Yonge Street, Toronto ON M5G 2K2, Canada]
# 36                    [Yonge St., Toronto ON, Canada]
# 37  [10 Dundas Street East, #124, Toronto ON M5B 2...
# 38  [228 QUEEN STREET WEST, Toronto ON M5V 1Z6, Ca...
# 39             [Front and Jervis, Toronto ON, Canada]
# 40                                           [Canada]
# 41                                           [Canada]
# 42  [521 King St. W (at Brant St.), Toronto ON M5V...
# 43               [772 College St, Toronto ON, Canada]
# 44  [232 wellington street west (John), Toronto ON...
# 45  [290 Adelaide Street West, Toronto ON M5V 1P6,...
# 46  [109 FRONT STREET EAST, Toronto ON M5E 1C7, Ca...
# 47  [1193 BLOOR STREET WEST, Toronto ON M6H 1N4, C...
# 48   [600 University Ave, Toronto ON M5G 1X5, Canada]
# 49  [255 E Dundas St., Ste E, Toronto ON M5A 1Z7, ...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.65651263631174...  43.656513 -79.377242
# 1   [{'label': 'display', 'lat': 43.650891, 'lng':...  43.650891 -79.378632
# 2   [{'label': 'display', 'lat': 43.64608978691595...  43.646090 -79.379776
# 3   [{'label': 'display', 'lat': 43.65245635983421...  43.652456 -79.374938
# 4   [{'label': 'display', 'lat': 43.66021482917061...  43.660215 -79.382571
# 5   [{'label': 'display', 'lat': 43.645145, 'lng':...  43.645145 -79.389296
# 6   [{'label': 'display', 'lat': 43.66378730691813...  43.663787 -79.380224
# 7   [{'label': 'display', 'lat': 43.64405883528329...  43.644059 -79.388815
# 8   [{'label': 'display', 'lat': 43.64491920354413...  43.644919 -79.391844
# 9   [{'label': 'display', 'lat': 43.64837838784134...  43.648378 -79.371578
# 10  [{'label': 'display', 'lat': 43.64327168873745...  43.643272 -79.391836
# 11  [{'label': 'display', 'lat': 43.63904861970403...  43.639049 -79.386323
# 12  [{'label': 'display', 'lat': 43.64794272203376...  43.647943 -79.395647
# 13  [{'label': 'display', 'lat': 43.6546222, 'lng'...  43.654622 -79.364211
# 14  [{'label': 'display', 'lat': 43.64711589206853...  43.647116 -79.404152
# 15  [{'label': 'display', 'lat': 43.663488, 'lng':...  43.663488 -79.367550
# 16  [{'label': 'display', 'lat': 43.65433248862573...  43.654332 -79.391107
# 17  [{'label': 'display', 'lat': 43.66329982959619...  43.663300 -79.402317
# 18  [{'label': 'display', 'lat': 43.65865441760277...  43.658654 -79.350955
# 19  [{'label': 'display', 'lat': 43.656972, 'lng':...  43.656972 -79.378484
# 20  [{'label': 'display', 'lat': 43.66677726238188...  43.666777 -79.403529
# 21  [{'label': 'display', 'lat': 43.62223658034779...  43.622237 -79.378935
# 22  [{'label': 'display', 'lat': 43.652144, 'lng':...  43.652144 -79.381118
# 23  [{'label': 'display', 'lat': 43.64829, 'lng': ...  43.648290 -79.387505
# 24  [{'label': 'display', 'lat': 43.65621225108779...  43.656212 -79.383430
# 25  [{'label': 'display', 'lat': 43.650696, 'lng':...  43.650696 -79.384149
# 26  [{'label': 'display', 'lat': 43.66503110796393...  43.665031 -79.411218
# 27  [{'label': 'display', 'lat': 43.65715687330202...  43.657157 -79.374002
# 28  [{'label': 'display', 'lat': 43.649834, 'lng':...  43.649834 -79.374809
# 29  [{'label': 'display', 'lat': 43.65708784629449...  43.657088 -79.374123
# 30  [{'label': 'display', 'lat': 43.662363, 'lng':...  43.662363 -79.383626
# 31  [{'label': 'display', 'lat': 43.65948714793604...  43.659487 -79.385207
# 32  [{'label': 'display', 'lat': 43.65452912849596...  43.654529 -79.390095
# 33  [{'label': 'display', 'lat': 43.65787913074364...  43.657879 -79.381729
# 34  [{'label': 'display', 'lat': 43.651347, 'lng':...  43.651347 -79.397020
# 35  [{'label': 'display', 'lat': 43.65933831769298...  43.659338 -79.382260
# 36  [{'label': 'display', 'lat': 43.659155, 'lng':...  43.659155 -79.383018
# 37  [{'label': 'display', 'lat': 43.656518, 'lng':...  43.656518 -79.380015
# 38  [{'label': 'display', 'lat': 43.65010669805269...  43.650107 -79.390002
# 39  [{'label': 'display', 'lat': 43.6476, 'lng': -...  43.647600 -79.373500
# 40  [{'label': 'display', 'lat': 43.65833282470703...  43.658333 -79.379135
# 41  [{'label': 'display', 'lat': 43.659928, 'lng':...  43.659928 -79.385044
# 42  [{'label': 'display', 'lat': 43.64479341856585...  43.644793 -79.398230
# 43  [{'label': 'display', 'lat': 43.6550191, 'lng'...  43.655019 -79.420346
# 44  [{'label': 'display', 'lat': 43.64511516109716...  43.645115 -79.389406
# 45  [{'label': 'display', 'lat': 43.64787, 'lng': ...  43.647870 -79.391136
# 46  [{'label': 'display', 'lat': 43.6496176296263,...  43.649618 -79.371091
# 47  [{'label': 'display', 'lat': 43.6591696173578,...  43.659170 -79.438657
# 48  [{'label': 'display', 'lat': 43.657524, 'lng':...  43.657524 -79.390724
# 49  [{'label': 'display', 'lat': 43.65797992914537...  43.657980 -79.372496
#
#               neighborhood postalCode state                        id
# 0                      NaN    M5B 1Z2    ON  4b2438f6f964a520126424e3
# 1                      NaN    M5C 1W4    ON  552ff1d1498e5f41b0ccb3bd
# 2                      NaN        M5J    ON  4ca62112f47ea14380845d21
# 3                      NaN    M5C 1N9    ON  59f28358acb00b73e36783d6
# 4                      NaN        NaN    ON  4af5d885f964a520b2fd21e3
# 5                      NaN    M5V 3W1    ON  5690363d498e0b868217831d
# 6                      NaN    M4Y 2C5    ON  4b5fdb7ff964a520ebce29e3
# 7                      NaN    M5V 3G5    ON  4dde735f7d8bb03c06b3db73
# 8                      NaN    M5V 3P5    ON  4af23cabf964a520d4e621e3
# 9                      NaN    M5E 1C3    ON  4cdd8afb78ddf04dfbf29498
# 10                     NaN    M5V 3S8    ON  4b7f161bf964a5206e1530e3
# 11                     NaN        NaN    ON  4bccdaca68f976b036686383
# 12                     NaN        NaN    ON  4adc9f99f964a520092e21e3
# 13                     NaN    M5A 2Z1    ON  5968973e93bd637ca76c60c8
# 14                     NaN    M6J 1E8    ON  4bc3a04cabf49521650bc493
# 15                     NaN        NaN    ON  4bf4172998ac0f474f9163a8
# 16                     NaN        NaN    ON  4b50edc9f964a5201c3927e3
# 17                     NaN    M5S 2H7    ON  4ad4c05ff964a52014f720e3
# 18                     NaN    M4M 1G8    ON  4b8095c0f964a520d47e30e3
# 19                     NaN    M5B 1Y2    ON  5c53a0aea2a6ce002c9e3806
# 20                     NaN    M5S 1W5    ON  4ae27484f964a520648e21e3
# 21                     NaN        NaN    ON  4ca36ac2b0ff8cfa4d24b75e
# 22                     NaN        NaN    ON  4c787c9181bca0936180fa14
# 23  Entertainment District    M5H 1W7    ON  5c789831180b91003915b599
# 24                     NaN    M5G 2M6    ON  4b7ddd2cf964a52001d82fe3
# 25                     NaN    M5H 2G4    ON  5a9b3ef3d1a40244fc9e8373
# 26                     NaN    M5S 1Y6    ON  4aef9318f964a52059d921e3
# 27                     NaN        NaN    ON  4e8684e2b803d7b67f5c7c3f
# 28                     NaN    M5C 2V8    ON  5b0ed8c9d0a149002c9927bb
# 29                     NaN    M5A 4R6    ON  4bd33bd6b221c9b6f235d9d0
# 30                     NaN    M4Y 3B3    ON  5f06d9a7499da0761966014a
# 31                     NaN    M5G 2R2    ON  4bca3d4cb6c49c74e7209091
# 32                     NaN    M7A 1G1    ON  504f3f4dc84ca7853139f4c2
# 33                     NaN    M5B 1R8    ON  4ce805f68ef78cfa1675979b
# 34                     NaN    M5T 2E2    ON  5aa59c977564f726ae4069c6
# 35                     NaN    M5G 2K2    ON  59ecdaae029a5529f5e8773c
# 36                     NaN        NaN    ON  524a5b79498e2a7a5945a8e1
# 37                     NaN    M5B 2G9    ON  5615b6c4498e3c32c67ad78f
# 38                     NaN    M5V 1Z6    ON  4b6b0234f964a52043ec2be3
# 39                     NaN        NaN    ON  522b40ce11d2a3a8907697a9
# 40                     NaN        NaN   NaN  4ffc93cce4b001c1ca261790
# 41                     NaN        NaN   NaN  5129ce16e4b0447baceddbd1
# 42                     NaN    M5V 1K4    ON  4aeb18d8f964a5204bbe21e3
# 43                     NaN        NaN    ON  4bb6f2f52f70c9b6232e8630
# 44                     NaN        NaN    ON  4aeef7caf964a520ecd421e3
# 45                     NaN    M5V 1P6    ON  5b7331b00d8a0f002c4849bf
# 46                     NaN    M5E 1C7    ON  50a05c37e4b0577f9f1f1ba6
# 47                     NaN    M6H 1N4    ON  4b8216c4f964a5203dca30e3
# 48                     NaN    M5G 1X5    ON  57c86064498e77ac07cf2730
# 49                     NaN    M5A 1Z7    ON  5514dc35498e1babfbd4f5f6

# %%
# names of pizza restourants
df_filtered.name
# Out:
# 0                                Pizza Pizza
# 1                              Mamma's Pizza
# 2                                 Pizza 2 Go
# 3                             Domino's Pizza
# 4                                Amato Pizza
# 5                                  JZs Pizza
# 6                              Express Pizza
# 7                               Boston Pizza
# 8             Pizza Rustica Restaurant & Bar
# 9               St. Lawrence Pizza and Pasta
# 10                                Pizza Nova
# 11                             Mamma's Pizza
# 12                             Mamma's Pizza
# 13                                 241 Pizza
# 14                               Pizza Pizza
# 15                                 241 Pizza
# 16                                 Pizzaiolo
# 17       Papa Ceo Fine Italian Foods & Pizza
# 18                               Pizza Pizza
# 19                                Pizza Shab
# 20                               Pizza Pizza
# 21                               Pizza Pizza
# 22    Classic italian style pizza food truck
# 23                               Pizza Forno
# 24                    Vinnie's Pizza & Pasta
# 25                        The Good Son Pizza
# 26                               Pizza Pizza
# 27                                Pizza Nova
# 28                             Pizza Rustica
# 29                                 Pizza Hut
# 30                            Domino’s Pizza
# 31                               Pizza Pizza
# 32                          Freshslice Pizza
# 33                               Pizza Pizza
# 34                         Big Trouble Pizza
# 35                              Boston Pizza
# 36                             Mamma's Pizza
# 37                               Blaze Pizza
# 38                               Pizza Pizza
# 39                             Pizza & Pasta
# 40                           Colombo's Pizza
# 41                            Andrew's Pizza
# 42                                 Pizzaiolo
# 43                     Delisso Pizza & Wings
# 44                    Pizza Rustica Boutique
# 45                           Za Pizza Bistro
# 46                               Pizza Pizza
# 47                               Pizza Pizza
# 48                          King David Pizza
# 49                         Papa John's Pizza
# Name: name, dtype: object

# %%
# now let's creat a map centered around toronto and add yellow circle the center of toronto
pizza_map = folium.Map(location=[latitude, longitude], zoom_start=15)
folium.CircleMarker([latitude, longitude], fill=True, fill_color="yellow", fill_opacity=0.7, popup="Toronto Center", radius=10).add_to(pizza_map)
pizza_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# now let's add the places that sells pizza as blue markers in the map and display it's name
for lat, lng, label in zip(df_filtered.lat, df_filtered.lng, df_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(pizza_map)
pizza_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# closest 10 pizza plces to the center of toronto
closest_pizza_places = df_filtered.sort_values(by=['distance'], ascending=True)
closest_pizza_places.reset_index(inplace=True)
closest_pizza_places = closest_pizza_places[0:10]
closest_pizza_places.head(10)
# Out:
#    index                                    name   categories  \
# 0     24                  Vinnie's Pizza & Pasta  Pizza Place
# 1     22  Classic italian style pizza food truck   Food Truck
# 2     25                      The Good Son Pizza  Pizza Place
# 3     37                             Blaze Pizza  Pizza Place
# 4     32                        Freshslice Pizza  Pizza Place
# 5     33                             Pizza Pizza  Pizza Place
# 6     16                               Pizzaiolo  Pizza Place
# 7      1                           Mamma's Pizza  Pizza Place
# 8     19                              Pizza Shab  Pizza Place
# 9     36                           Mamma's Pizza  Pizza Place
#
#                        address  cc     city country          crossStreet  \
# 0                  595 Bay St.  CA  Toronto  Canada     in Atrium On Bay
# 1                   CNE Midway  CA  Toronto  Canada                  NaN
# 2            111 Richmond St w  CA  Toronto  Canada                  NaN
# 3  10 Dundas Street East, #124  CA  Toronto  Canada                  NaN
# 4       250 Dundas Street West  CA  Toronto  Canada  Dundas & University
# 5             346 YONGE STREET  CA  Toronto  Canada                  NaN
# 6                289 Dundas St  CA  Toronto  Canada         at McCaul St
# 7                 127 Yonge St  CA  Toronto  Canada                  NaN
# 8                          NaN  CA  Toronto  Canada                  NaN
# 9                    Yonge St.  CA  Toronto  Canada                  NaN
#
#    distance                                   formattedAddress  \
# 0       265  [595 Bay St. (in Atrium On Bay), Toronto ON M5...
# 1       322                   [CNE Midway, Toronto ON, Canada]
# 2       357    [111 Richmond St w, Toronto ON M5H 2G4, Canada]
# 3       450  [10 Dundas Street East, #124, Toronto ON M5B 2...
# 4       472  [250 Dundas Street West (Dundas & University),...
# 5       487     [346 YONGE STREET, Toronto ON M5B 1R8, Canada]
# 6       550  [289 Dundas St (at McCaul St), Toronto ON, Can...
# 7       566         [127 Yonge St, Toronto ON M5C 1W4, Canada]
# 8       578                       [Toronto ON M5B 1Y2, Canada]
# 9       593                    [Yonge St., Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65621225108779...  43.656212 -79.383430
# 1  [{'label': 'display', 'lat': 43.652144, 'lng':...  43.652144 -79.381118
# 2  [{'label': 'display', 'lat': 43.650696, 'lng':...  43.650696 -79.384149
# 3  [{'label': 'display', 'lat': 43.656518, 'lng':...  43.656518 -79.380015
# 4  [{'label': 'display', 'lat': 43.65452912849596...  43.654529 -79.390095
# 5  [{'label': 'display', 'lat': 43.65787913074364...  43.657879 -79.381729
# 6  [{'label': 'display', 'lat': 43.65433248862573...  43.654332 -79.391107
# 7  [{'label': 'display', 'lat': 43.650891, 'lng':...  43.650891 -79.378632
# 8  [{'label': 'display', 'lat': 43.656972, 'lng':...  43.656972 -79.378484
# 9  [{'label': 'display', 'lat': 43.659155, 'lng':...  43.659155 -79.383018
#
#   neighborhood postalCode state                        id
# 0          NaN    M5G 2M6    ON  4b7ddd2cf964a52001d82fe3
# 1          NaN        NaN    ON  4c787c9181bca0936180fa14
# 2          NaN    M5H 2G4    ON  5a9b3ef3d1a40244fc9e8373
# 3          NaN    M5B 2G9    ON  5615b6c4498e3c32c67ad78f
# 4          NaN    M7A 1G1    ON  504f3f4dc84ca7853139f4c2
# 5          NaN    M5B 1R8    ON  4ce805f68ef78cfa1675979b
# 6          NaN        NaN    ON  4b50edc9f964a5201c3927e3
# 7          NaN    M5C 1W4    ON  552ff1d1498e5f41b0ccb3bd
# 8          NaN    M5B 1Y2    ON  5c53a0aea2a6ce002c9e3806
# 9          NaN        NaN    ON  524a5b79498e2a7a5945a8e1

# %%
ax1 = closest_pizza_places.plot.bar(x="name", y="distance", figsize=(12 , 8))
ax1

# %%
ax2 = closest_pizza_places.plot.barh(x="name", y="distance", figsize=(12 , 8))
ax2

# %%
# creating a map of closest 10 places that is selling pizza
closest_pizza_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add red circle marker in the center of toronto 
folium.CircleMarker([latitude, longitude], fill=True, fill_color="red", fill_opacity=0.7, popup="Toronto Center", radius=12).add_to(closest_pizza_map)

# add blue markers in the top 10 closest places to the center of toronto which is selling pizza
for lat, lng, label in zip(closest_pizza_places.lat, closest_pizza_places.lng, closest_pizza_places.name):
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(closest_pizza_map)
    
closest_pizza_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ID's of the 10 most closest pizza places

pizza_list = ["4b7ddd2cf964a52001d82fe3", 
              "4c787c9181bca0936180fa14", 
              "5a9b3ef3d1a40244fc9e8373", 
              "5615b6c4498e3c32c67ad78f", 
              "504f3f4dc84ca7853139f4c2", 
              "4ce805f68ef78cfa1675979b", 
              "4b50edc9f964a5201c3927e3", 
              "552ff1d1498e5f41b0ccb3bd", 
              "5c53a0aea2a6ce002c9e3806", 
              "524a5b79498e2a7a5945a8e1"
             ]

# %%
CLIENT_ID1 = "WREKFROBMZAO540BWRQR0QW1XOB0WKCBRBKKUB1M51RADAKW"
CLIENT_SECRET1 = "Y2RGQNOH2ATHIWJJQWZST2W2OZIPCWHZ0RDCOZZTPAU4JCM2"

for pp in pizza_list:
    
    venue_idd = pp 
    url2 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_idd, CLIENT_ID1, CLIENT_SECRET1, VERSION)

    result2 = requests.get(url2).json()
    try:
        print(result2['response']['venue']['rating'])
    except:
        print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# 8.5
# This venue has not been rated yet.
# 5.3
# 6.5
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.

# %%
# and we coclude of that , that the 4th, 6th, 7th who only have a rating
# let's put their ratings in a list

rating_list = [8.5, 5.3, 6.5]
places_with_rating =  ["Blaze Pizza", "Pizza Pizza", "Pizzaiolo"]
pizza_ratings_dictionary = {"Place":places_with_rating, "Rate":rating_list}
df_top_nearby3 = pd.DataFrame(pizza_ratings_dictionary, columns=['Place', 'Rate'])

#creat a columns for the coordinates of the places and add it to the dataframe

lat_list = {43.656518:"Blaze Pizza", 43.657879:"Pizza Pizza", 43.654332:"Pizzaiolo"}
lon_list = {-79.380015:"Blaze Pizza", -79.381729:"Pizza Pizza", -79.391107:"Pizzaiolo"}

df_top_nearby3["latitude"] = lat_list
df_top_nearby3["longitude"] = lon_list

df_top_nearby3
# Out:
#          Place  Rate   latitude  longitude
# 0  Blaze Pizza   8.5  43.656518 -79.380015
# 1  Pizza Pizza   5.3  43.657879 -79.381729
# 2    Pizzaiolo   6.5  43.654332 -79.391107

# %%
ax = df_top_nearby3.plot.bar(x="Place", y="Rate", figsize=(8, 6))
ax

# %%
top3_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add red circle marker in the center of toronto 
folium.CircleMarker([latitude, longitude], fill=True, fill_color="red", fill_opacity=0.7, popup="Toronto Center", radius=12).add_to(top3_map)

# add blue markers in the top 3 closest places to the center of toronto which is selling pizza
for lat, lng, label in zip(df_top_nearby3.latitude, df_top_nearby3.longitude, df_top_nearby3.Place):
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(top3_map)
    
top3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <p><b> And we eventuly concolude that "Blaze Pizza" is THE BEST and NEAREST Pizza Restourant you can visit if you are in the centere of Toronto<p><b>
